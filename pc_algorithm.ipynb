# %%
import pandas as pd
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils

# %%
# Duration
data = pd.read_excel("cleaned_duration.xlsx")
# Convert DataFrame to Numpy array
data_numpy = data.values  
cg_duration = pc(data_numpy)
# Out:
# Depth=3, working on node 8: 100%|██████████| 9/9 [00:00<00:00, 515.54it/s]

# %%
# visualization using pydot
cg_duration.draw_pydot_graph()

# %%
#save the graph
pyd = GraphUtils.to_pydot(cg_duration.G)
pyd.write_png('pc_duration.png')

# %%
# Stainless steel
data = pd.read_excel("cleaned_steel_energy.xlsx")
# Convert DataFrame to Numpy array
data_numpy = data.values  
cg_steel = pc(data_numpy)
# Out:
# Depth=5, working on node 7: 100%|██████████| 8/8 [00:00<?, ?it/s]

# %%
# visualization using pydot
cg_steel.draw_pydot_graph()

# %%
#save the graph
pyd = GraphUtils.to_pydot(cg_duration.G)
pyd.write_png('pc_steel.png')
